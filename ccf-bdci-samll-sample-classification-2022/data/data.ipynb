# %%
import numpy as np
import pandas as pd

train_df = pd.read_json('train.json', encoding='utf8', lines=True)
testA_df = pd.read_json('testA.json', encoding='utf8', lines=True)
train_df
# Out:
#                                    id              title           assignee  \
# 0    538f267d2e6fba48b1286fb7f1499fe7  一种信号的发送方法及基站、用户设备           华为技术有限公司
# 1    635a7d4b6358b6ff24a324bb871505db     一种5G通讯电缆故障监控系统  中铁二十二局集团电气化工程有限公司
# 2    aaf98d6bfe1932cf1a262812ca59d1ba        一种测试方法及电子设备       腾讯科技(北京)有限公司
# 3    ad49c9ba6412452d9b25071af702f4fb          天线方位角调节装置     武汉虹信通信技术有限责任公司
# 4    ffa2d7617b3eac3a1d7df01e5bb515a2        光纤老化预测方法及装置       新华三大数据技术有限公司
# ..                                ...                ...                ...
# 953  6af8c4c55c93ee38b8912db4576b3cfc        一种信息处理方法及装置       腾讯科技(深圳)有限公司
# 954  bc94427b0ae4c5a734ef7d32d6a1b9ea        一种适用于安防的广告机    靖江天元爱尔瑞电子科技有限公司
# 955  2b1d9b24b86b2e49f842bd2c93cb865c      一种广告投放控制方法及装置       阿里巴巴(中国)有限公司
# 956  674baad2739c09bc9cc759322a0085c7      一种广告数据推荐方法和系统       北京奇艺世纪科技有限公司
# 957  94b8d5a69a04bc931bb2d65ea95fc9b2     一种基于大数据的广告推送系统     浙江华坤道威数据科技有限公司
#
#                                               abstract  label_id
# 0    一种信号的发送方法及基站、用户设备。在一个子帧中为多个用户设备配置的参考信号的符号和数据的符...         0
# 1    本发明公开了一种5G通讯电缆故障监控系统，包括信号采样模块、补偿反馈模块，所述信号采样模块对...         0
# 2    本发明提供了一种测试方法及电子设备，该方法包括：基于选取的测试任务确定目标测试用例，根据所述...         0
# 3    一种天线方位角调节装置，包括对向的两个8字形支架(101)、动力输入电机(102)、主动齿轮...         0
# 4    本申请提供一种光纤老化预测方法及装置，所述方法包括：获取待测光纤模块可接收的光信号的告警阈值...         0
# ..                                                 ...       ...
# 953  本发明公开了一种信息处理方法，所述方法包括：第一进程获取来自多个查询请求端的多个数据请求，所...        35
# 954  本实用新型公开了一种适用于安防的广告机，包括支撑架，支撑架的上端设置有显示屏，显示屏与壳体配...        35
# 955  本发明公开了一种广告投放控制方法及装置，以解决现有技术中基于地域定向的广告投放方式准确度较低...        35
# 956  本发明公开了一种广告数据推荐方法和系统。所述方法包括：接收到用户对目标广告数据的浏览请求后，...        35
# 957  本发明公开了一种基于大数据的广告推送系统，包括用户信息采集模块、大数据采集模块、数据处理模块...        35
#
# [958 rows x 5 columns]

# %%
testA_df
# Out:
#                                      id                      title  \
# 0      003fd481e65ddc070e38ae05002e16e2       一种耐磨、抗粘钢复合涂层、制备方法及应用
# 1      549a1cd8228bd10f18395a0625fcc70d   一种用于提高橡胶抗湿滑性的树脂的制备方法及其应用
# 2      f09c4c0332f8966400e06f4def9f1a6d    有机硅改性丙烯酸树脂超亲水防雾涂料及其制作方法
# 3      06598dd8f3ab092acf2a55dce8be5621          一种空调系统及其控制方法、控制装置
# 4      e70177ba6a54d08abecd80a60fdd9f52        资源申请、分配方法，UE及网络控制单元
# ...                                 ...                        ...
# 20834  befab80c8c6cf6f8db5a4ee3b9e22020       由低合金碳钢制成的螺钉和制造该螺钉的方法
# 20835  b41abe927240b1ab73b1cb0fca2d9970              一种铸造铝合金及其制备方法
# 20836  c0fd3051ce51166e80b9922c97e2f7a4         一种显示面板及生成随机图块坐标的方法
# 20837  4c89a2b2bd405456e316a35411297b0f  一种确定机器类通信下行控制信道重复次数的方法及基站
# 20838  07870847de45f9e8fd081bd2edc7c252    一类层状钙钛矿型纳米氧化物的超级电容器电极材料
#
#              assignee                                           abstract
# 0      安徽马钢表面技术股份有限公司  本发明公开了一种耐磨、抗粘钢复合涂层、制备方法及应用，包括基体和基体上由内到外依次设置的过渡...
# 1        江苏麒祥高新材料有限公司  本发明公开了一种用于提高橡胶抗湿滑性的树脂的制备方法，第一步：将R树脂和B官能团化合物进行反...
# 2                重庆大学  本发明涉及涂料制造领域，本发明公开了一种含有磺酸季铵盐的有机硅改性丙烯酸树脂超亲水低温防雾涂...
# 3          海尔智家股份有限公司  本发明涉及空调领域，公开了一种空调系统，包括室外机和太阳能供热系统，所述太阳能供热系统包括：...
# 4          中兴通讯股份有限公司  本发明实施例公开了一种资源申请方法及装置，所述方法包括：向网络控制单元发送低时延业务信息；接...
# ...               ...                                                ...
# 20834       伊卓特有限两合公司  本发明涉及一种螺钉，该螺钉具有头部、邻接的保持段和功能端。所述螺钉用于自攻螺钉。所述功能端的...
# 20835    中国兵器工业第五九研究所  本发明提供了一种铸造铝合金及其制备方法，铸造铝合金成分包括：Si：7.5～8.5%、Cu：2...
# 20836     上海天马微电子有限公司  本发明提供一种显示面板，显示面板的图块具有随机排布的特性，能够消除由于周期性排布带来的鬼影问...
# 20837       电信科学技术研究院  本发明实施例涉及无线通信技术领域，特别涉及一种确定机器类通信下行控制信道重复次数的方法及基站...
# 20838            云南大学  本发明涉及一类层状钙钛矿型纳米氧化物的超级电容器电极材料，它具有化学式为LXMO的214型层...
#
# [20839 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
plt.figure(figsize=(16, 10))
sns.set(font='SimHei', font_scale=1.2)  # 解决Seaborn中文显示问题并调整字体大小
sns.countplot(y='label_id', data=train_df)
plt.title('training set labels')
plt.savefig('train-label.png', dpi=150)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

train_labeled_df = pd.read_csv('train/train6403_49oversampling.tsv', sep='\t', encoding='utf8', header=0,
                               names=['label_id', 'text'])

plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
plt.figure(figsize=(16, 10))
sns.set(font='SimHei', font_scale=1.2)  # 解决Seaborn中文显示问题并调整字体大小
sns.countplot(y='label_id', data=train_labeled_df)
plt.title('train-testA set labels')
plt.savefig('train-testA-label.png', dpi=150)

# %%
abstract = np.asarray(train_df['abstract']).transpose().tolist()
abstract_length = [len(a) for a in abstract]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(abstract_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
title = np.asarray(train_df['title']).transpose().tolist()
title_length = [len(t) for t in title]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(title_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
assignee = np.asarray(train_df['assignee']).transpose().tolist()
assignee_length = [len(a) for a in assignee]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(assignee_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
abstract = np.asarray(testA_df['abstract']).transpose().tolist()
abstract_length = [len(a) for a in abstract]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(abstract_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
title = np.asarray(testA_df['title']).transpose().tolist()
title_length = [len(t) for t in title]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(title_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
assignee = np.asarray(testA_df['assignee']).transpose().tolist()
assignee_length = [len(a) for a in assignee]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(assignee_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
train_df['title'] = train_df['title'].apply(lambda x: x.strip())
train_df['abstract'] = train_df['abstract'].fillna('').apply(lambda x: x.strip())
train_df['text'] = train_df['title'].str.lower() + '[SEP]' + train_df['abstract'].str.lower()
# train_df['text'] = "本专利是" + train_df['title'] + "，属于" + train_df['assignee'] + "。具体是" + train_df['abstract']

testA_df['title'] = testA_df['title'].apply(lambda x: x.strip())
testA_df['abstract'] = testA_df['abstract'].fillna('').apply(lambda x: x.strip())
testA_df['text'] = testA_df['title'].str.lower() + '[SEP]' + testA_df['abstract'].str.lower()
# testA_df['text'] = "本专利是" + testA_df['title'] + "，属于" + testA_df['assignee'] + "。具体是" + testA_df['abstract']

train_df
# Out:
#                                    id              title           assignee  \
# 0    538f267d2e6fba48b1286fb7f1499fe7  一种信号的发送方法及基站、用户设备           华为技术有限公司
# 1    635a7d4b6358b6ff24a324bb871505db     一种5G通讯电缆故障监控系统  中铁二十二局集团电气化工程有限公司
# 2    aaf98d6bfe1932cf1a262812ca59d1ba        一种测试方法及电子设备       腾讯科技(北京)有限公司
# 3    ad49c9ba6412452d9b25071af702f4fb          天线方位角调节装置     武汉虹信通信技术有限责任公司
# 4    ffa2d7617b3eac3a1d7df01e5bb515a2        光纤老化预测方法及装置       新华三大数据技术有限公司
# ..                                ...                ...                ...
# 953  6af8c4c55c93ee38b8912db4576b3cfc        一种信息处理方法及装置       腾讯科技(深圳)有限公司
# 954  bc94427b0ae4c5a734ef7d32d6a1b9ea        一种适用于安防的广告机    靖江天元爱尔瑞电子科技有限公司
# 955  2b1d9b24b86b2e49f842bd2c93cb865c      一种广告投放控制方法及装置       阿里巴巴(中国)有限公司
# 956  674baad2739c09bc9cc759322a0085c7      一种广告数据推荐方法和系统       北京奇艺世纪科技有限公司
# 957  94b8d5a69a04bc931bb2d65ea95fc9b2     一种基于大数据的广告推送系统     浙江华坤道威数据科技有限公司
#
#                                               abstract  label_id  \
# 0    一种信号的发送方法及基站、用户设备。在一个子帧中为多个用户设备配置的参考信号的符号和数据的符...         0
# 1    本发明公开了一种5G通讯电缆故障监控系统，包括信号采样模块、补偿反馈模块，所述信号采样模块对...         0
# 2    本发明提供了一种测试方法及电子设备，该方法包括：基于选取的测试任务确定目标测试用例，根据所述...         0
# 3    一种天线方位角调节装置，包括对向的两个8字形支架(101)、动力输入电机(102)、主动齿轮...         0
# 4    本申请提供一种光纤老化预测方法及装置，所述方法包括：获取待测光纤模块可接收的光信号的告警阈值...         0
# ..                                                 ...       ...
# 953  本发明公开了一种信息处理方法，所述方法包括：第一进程获取来自多个查询请求端的多个数据请求，所...        35
# 954  本实用新型公开了一种适用于安防的广告机，包括支撑架，支撑架的上端设置有显示屏，显示屏与壳体配...        35
# 955  本发明公开了一种广告投放控制方法及装置，以解决现有技术中基于地域定向的广告投放方式准确度较低...        35
# 956  本发明公开了一种广告数据推荐方法和系统。所述方法包括：接收到用户对目标广告数据的浏览请求后，...        35
# 957  本发明公开了一种基于大数据的广告推送系统，包括用户信息采集模块、大数据采集模块、数据处理模块...        35
#
#                                                   text
# 0    本专利是一种信号的发送方法及基站、用户设备，属于华为技术有限公司。具体是一种信号的发送方法及...
# 1    本专利是一种5G通讯电缆故障监控系统，属于中铁二十二局集团电气化工程有限公司。具体是本发明公...
# 2    本专利是一种测试方法及电子设备，属于腾讯科技(北京)有限公司。具体是本发明提供了一种测试方法...
# 3    本专利是天线方位角调节装置，属于武汉虹信通信技术有限责任公司。具体是一种天线方位角调节装置，...
# 4    本专利是光纤老化预测方法及装置，属于新华三大数据技术有限公司。具体是本申请提供一种光纤老化预...
# ..                                                 ...
# 953  本专利是一种信息处理方法及装置，属于腾讯科技(深圳)有限公司。具体是本发明公开了一种信息处理...
# 954  本专利是一种适用于安防的广告机，属于靖江天元爱尔瑞电子科技有限公司。具体是本实用新型公开了一...
# 955  本专利是一种广告投放控制方法及装置，属于阿里巴巴(中国)有限公司。具体是本发明公开了一种广告...
# 956  本专利是一种广告数据推荐方法和系统，属于北京奇艺世纪科技有限公司。具体是本发明公开了一种广告...
# 957  本专利是一种基于大数据的广告推送系统，属于浙江华坤道威数据科技有限公司。具体是本发明公开了一...
#
# [958 rows x 6 columns]

# %%
train_df.drop(['id', 'title', 'assignee', 'abstract'], axis=1).to_csv('train2.tsv', sep='\t', index=None,
                                                                      header=['label_id', 'text'])
testA_df.drop(['id', 'title', 'assignee', 'abstract'], axis=1).to_csv('testA2.tsv', index=None, header=['text'])

# %%
train_df = pd.read_csv('train5940.tsv', sep='\t', encoding='utf8')
text = np.asarray(train_df['text']).transpose().tolist()
text_length = [len(t) for t in text]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(text_length), max(text_length), np.mean(text_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (<AxesSubplot:ylabel='Density'>, 1336, 270.2524395804834)

# %%
text_length.sort(reverse=True)
text_length
# Out:
# [653,
#  412,
#  402,
#  398,
#  393,
#  385,
#  377,
#  374,
#  373,
#  367,
#  359,
#  358,
#  358,
#  357,
#  357,
#  354,
#  354,
#  351,
#  349,
#  349,
#  348,
#  347,
#  345,
#  344,
#  344,
#  343,
#  342,
#  340,
#  338,
#  338,
#  337,
#  336,
#  335,
#  335,
#  334,
#  333,
#  332,
#  331,
#  331,
#  330,
#  330,
#  330,
#  329,
#  329,
#  329,
#  329,
#  328,
#  328,
#  328,
#  328,
#  328,
#  328,
#  328,
#  328,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  296,
#  296,
#  296,
#  296,
#  296,
#  296,
#  296,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  291,
#  291,
#  291,
#  291,
#  291,
#  291,
#  291,
#  291,
#  291,
#  291,
#  290,
#  290,
#  290,
#  290,
#  289,
#  289,
#  289,
#  289,
#  289,
#  289,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  287,
#  287,
#  287,
#  287,
#  287,
#  287,
#  287,
#  286,
#  286,
#  286,
#  286,
#  286,
#  286,
#  286,
#  286,
#  286,
#  286,
#  285,
#  285,
#  285,
#  285,
#  285,
#  285,
#  284,
#  284,
#  284,
#  283,
#  283,
#  283,
#  283,
#  282,
#  282,
#  282,
#  282,
#  281,
#  281,
#  281,
#  281,
#  281,
#  281,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  277,
#  277,
#  277,
#  277,
#  277,
#  277,
#  277,
#  276,
#  276,
#  276,
#  276,
#  276,
#  276,
#  276,
#  275,
#  275,
#  275,
#  275,
#  275,
#  275,
#  275,
#  275,
#  274,
#  274,
#  273,
#  273,
#  273,
#  273,
#  273,
#  273,
#  272,
#  272,
#  272,
#  272,
#  272,
#  272,
#  272,
#  271,
#  271,
#  271,
#  271,
#  270,
#  270,
#  270,
#  270,
#  269,
#  269,
#  269,
#  268,
#  268,
#  268,
#  268,
#  267,
#  267,
#  267,
#  267,
#  267,
#  267,
#  267,
#  267,
#  267,
#  267,
#  266,
#  266,
#  265,
#  265,
#  264,
#  264,
#  264,
#  264,
#  263,
#  263,
#  262,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  259,
#  259,
#  259,
#  259,
#  259,
#  258,
#  258,
#  258,
#  258,
#  258,
#  257,
#  257,
#  257,
#  257,
#  256,
#  256,
#  256,
#  256,
#  256,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  254,
#  254,
#  254,
#  254,
#  254,
#  254,
#  254,
#  254,
#  253,
#  253,
#  253,
#  253,
#  253,
#  252,
#  252,
#  252,
#  252,
#  252,
#  251,
#  251,
#  251,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  249,
#  249,
#  249,
#  249,
#  248,
#  248,
#  248,
#  248,
#  247,
#  246,
#  246,
#  245,
#  245,
#  245,
#  244,
#  244,
#  244,
#  244,
#  244,
#  244,
#  243,
#  243,
#  243,
#  243,
#  242,
#  242,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  240,
#  239,
#  239,
#  238,
#  237,
#  237,
#  237,
#  236,
#  236,
#  235,
#  234,
#  234,
#  234,
#  233,
#  233,
#  233,
#  233,
#  232,
#  232,
#  232,
#  232,
#  230,
#  230,
#  230,
#  230,
#  230,
#  228,
#  228,
#  227,
#  227,
#  227,
#  225,
#  225,
#  225,
#  225,
#  224,
#  224,
#  224,
#  223,
#  222,
#  222,
#  222,
#  221,
#  221,
#  221,
#  220,
#  220,
#  219,
#  219,
#  219,
#  219,
#  217,
#  217,
#  217,
#  217,
#  215,
#  215,
#  215,
#  215,
#  214,
#  214,
#  213,
#  213,
#  213,
#  213,
#  213,
#  213,
#  213,
#  212,
#  212,
#  212,
#  212,
#  211,
#  211,
#  210,
#  209,
#  209,
#  209,
#  209,
#  209,
#  209,
#  208,
#  208,
#  207,
#  207,
#  207,
#  207,
#  207,
#  207,
#  206,
#  206,
#  205,
#  205,
#  205,
#  205,
#  205,
#  205,
#  205,
#  204,
#  204,
#  204,
#  202,
#  202,
#  202,
#  201,
#  200,
#  200,
#  200,
#  199,
#  199,
#  198,
#  198,
#  197,
#  197,
#  196,
#  196,
#  196,
#  195,
#  195,
#  195,
#  195,
#  194,
#  194,
#  193,
#  193,
#  193,
#  193,
#  192,
#  192,
#  191,
#  191,
#  190,
#  187,
#  187,
#  187,
#  186,
#  185,
#  183,
#  183,
#  182,
#  182,
#  182,
#  181,
#  181,
#  181,
#  180,
#  180,
#  180,
#  180,
#  180,
#  179,
#  178,
#  178,
#  177,
#  177,
#  175,
#  175,
#  173,
#  170,
#  169,
#  166,
#  166,
#  166,
#  163,
#  163,
#  160,
#  160,
#  158,
#  157,
#  157,
#  156,
#  156,
#  154,
#  152,
#  151,
#  150,
#  146,
#  146,
#  145,
#  144,
#  143,
#  141,
#  140,
#  139,
#  138,
#  136,
#  135,
#  135,
#  135,
#  134,
#  129,
#  126,
#  124,
#  123,
#  120,
#  119,
#  108,
#  103,
#  98,
#  97,
#  96,
#  93,
#  88,
#  75]

# %%
text = np.asarray(testA_df['text']).transpose().tolist()
text_length = [len(t) for t in text]

import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 15))
sns.set(font='SimHei', font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小
sns.distplot(text_length), max(text_length)
# Out:
# C:\Anaconda3\envs\pytorch39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (<AxesSubplot:ylabel='Density'>, 1336)

# %%
text_length.sort(reverse=True)
text_length
# Out:
# [1336,
#  762,
#  607,
#  571,
#  568,
#  550,
#  546,
#  536,
#  522,
#  522,
#  516,
#  515,
#  505,
#  505,
#  504,
#  502,
#  494,
#  490,
#  481,
#  479,
#  479,
#  469,
#  468,
#  468,
#  465,
#  463,
#  463,
#  457,
#  454,
#  453,
#  449,
#  449,
#  447,
#  446,
#  444,
#  442,
#  441,
#  440,
#  440,
#  437,
#  437,
#  436,
#  435,
#  435,
#  432,
#  431,
#  430,
#  429,
#  429,
#  428,
#  428,
#  428,
#  427,
#  427,
#  427,
#  427,
#  426,
#  426,
#  425,
#  424,
#  424,
#  424,
#  423,
#  419,
#  419,
#  419,
#  418,
#  418,
#  418,
#  417,
#  417,
#  416,
#  416,
#  415,
#  415,
#  414,
#  414,
#  412,
#  412,
#  412,
#  412,
#  411,
#  409,
#  409,
#  408,
#  408,
#  408,
#  408,
#  408,
#  408,
#  407,
#  407,
#  407,
#  407,
#  407,
#  407,
#  405,
#  405,
#  404,
#  404,
#  404,
#  404,
#  403,
#  403,
#  403,
#  402,
#  402,
#  402,
#  402,
#  401,
#  401,
#  401,
#  401,
#  401,
#  400,
#  398,
#  398,
#  398,
#  398,
#  398,
#  398,
#  397,
#  397,
#  397,
#  396,
#  396,
#  396,
#  395,
#  395,
#  395,
#  395,
#  394,
#  394,
#  393,
#  393,
#  393,
#  393,
#  392,
#  392,
#  392,
#  392,
#  391,
#  391,
#  391,
#  391,
#  391,
#  391,
#  390,
#  390,
#  390,
#  390,
#  389,
#  389,
#  389,
#  389,
#  389,
#  388,
#  388,
#  388,
#  388,
#  388,
#  388,
#  387,
#  387,
#  387,
#  387,
#  387,
#  387,
#  387,
#  386,
#  386,
#  386,
#  386,
#  386,
#  385,
#  385,
#  385,
#  385,
#  384,
#  384,
#  384,
#  383,
#  383,
#  382,
#  382,
#  382,
#  382,
#  382,
#  382,
#  381,
#  381,
#  381,
#  381,
#  381,
#  380,
#  380,
#  380,
#  380,
#  380,
#  380,
#  379,
#  379,
#  379,
#  379,
#  379,
#  379,
#  379,
#  378,
#  378,
#  378,
#  378,
#  378,
#  378,
#  378,
#  378,
#  378,
#  378,
#  377,
#  377,
#  377,
#  377,
#  377,
#  377,
#  377,
#  376,
#  376,
#  376,
#  376,
#  376,
#  376,
#  376,
#  376,
#  375,
#  375,
#  375,
#  375,
#  375,
#  375,
#  375,
#  375,
#  375,
#  375,
#  374,
#  374,
#  374,
#  373,
#  373,
#  373,
#  373,
#  373,
#  373,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  372,
#  371,
#  371,
#  371,
#  371,
#  371,
#  371,
#  371,
#  370,
#  370,
#  370,
#  370,
#  370,
#  370,
#  370,
#  370,
#  370,
#  370,
#  369,
#  369,
#  369,
#  369,
#  369,
#  369,
#  368,
#  368,
#  368,
#  368,
#  368,
#  368,
#  368,
#  368,
#  368,
#  368,
#  368,
#  368,
#  367,
#  367,
#  367,
#  367,
#  367,
#  367,
#  367,
#  367,
#  367,
#  367,
#  366,
#  366,
#  366,
#  366,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  365,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  364,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  363,
#  362,
#  362,
#  362,
#  362,
#  362,
#  362,
#  362,
#  362,
#  361,
#  361,
#  361,
#  361,
#  361,
#  361,
#  361,
#  361,
#  361,
#  361,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  360,
#  359,
#  359,
#  359,
#  359,
#  359,
#  359,
#  359,
#  359,
#  359,
#  359,
#  359,
#  359,
#  358,
#  358,
#  358,
#  358,
#  358,
#  358,
#  358,
#  358,
#  358,
#  358,
#  358,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  357,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  356,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  355,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  354,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  353,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  352,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  351,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  350,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  349,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  348,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  347,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  346,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  345,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  342,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  341,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  340,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  339,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  338,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  337,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  336,
#  ...]

# %% [markdown]
# # 加入训练集

# %%
import numpy as np
import pandas as pd

train_df = pd.read_csv('train_xlnet.tsv', sep='\t', encoding='utf8', header=0)
testA_labeled_df = pd.read_csv('test/testA_6409.tsv', sep='\t', encoding='utf8', header=0,
                               names=['label_id', 'text'])
train_labeled_df = pd.concat([train_df, testA_labeled_df])
train_labeled_df.to_csv('train/train6409.tsv', sep='\t', encoding='utf8', index=None)
train_labeled_df
# Out:
#        label_id                                               text
# 0             0  一种信号的发送方法及基站、用户设备<sep>一种信号的发送方法及基站、用户设备。在一个子帧中...
# 1             0  一种5g通讯电缆故障监控系统<sep>本发明公开了一种5g通讯电缆故障监控系统，包括信号采样...
# 2             0  一种测试方法及电子设备<sep>本发明提供了一种测试方法及电子设备，该方法包括：基于选取的测...
# 3             0  天线方位角调节装置<sep>一种天线方位角调节装置，包括对向的两个8字形支架(101)、动力...
# 4             0  光纤老化预测方法及装置<sep>本申请提供一种光纤老化预测方法及装置，所述方法包括：获取待测...
# ...         ...                                                ...
# 20834        23  由低合金碳钢制成的螺钉和制造该螺钉的方法<sep>本发明涉及一种螺钉，该螺钉具有头部、邻接的...
# 20835        13  一种铸造铝合金及其制备方法<sep>本发明提供了一种铸造铝合金及其制备方法，铸造铝合金成分包...
# 20836         9  一种显示面板及生成随机图块坐标的方法<sep>本发明提供一种显示面板，显示面板的图块具有随机...
# 20837         0  一种确定机器类通信下行控制信道重复次数的方法及基站<sep>本发明实施例涉及无线通信技术领域...
# 20838        21  一类层状钙钛矿型纳米氧化物的超级电容器电极材料<sep>本发明涉及一类层状钙钛矿型纳米氧化物...
#
# [21930 rows x 2 columns]

# %% [markdown]
# # 过采样

# %%
train_df[train_df['label_id'] == 32]
# Out:
#                                    id                    title  \
# 927  3d5a5fe91717dfd7b874c5d570c41f02  一种票据处理装置、方法及自助金融设备、终端设备
# 928  48b68c3d347ef3a992e9d9e286168a8d       一种基于生产模式的撮合匹配方法和装置
# 929  f944ef6c47b8bdc6e67aee8b172d4831           一种飞行器服务系统及通行方法
# 930  41f72dff5620a81b1f6f5996c608cd1b           保险信息处理方法、装置和系统
# 931  18999a0f466f07a970505d8fe961896e  基于多球面相机模型的大视野图像三维重构优化方法
#
#            assignee                                           abstract  \
# 927   深圳市怡化时代科技有限公司  本发明适用于金融交易技术领域，提供了一种票据处理装置、方法及自助金融设备、终端设备，包括存票...
# 928  北京京东金融科技控股有限公司  本发明公开了一种基于生产模式的撮合匹配方法和装置，涉及计算机技术领域。该方法的一具体实施方式...
# 929    广州煜煊信息科技有限公司  本发明涉及一种飞行器服务系统及通行方法。系统包括飞行器上的导航规划系统及空中区域的管理终端，...
# 930    平安科技(深圳)有限公司  本发明涉及一种保险信息处理方法，所述方法包括以下步骤：业务员终端获取用户信息；获取待办理险种...
# 931            浙江大学  本发明公开了一种基于多球面相机模型的大视野图像三维重构优化方法。基于不同立体对之间的视差和颜...
#
#      label_id
# 927        32
# 928        32
# 929        32
# 930        32
# 931        32

# %%
indices = [i for i in range(36)]
# indices = [3, 6, 7, 8, 11, 14, 15, 22, 24, 32, 35]
train_labeled_df = pd.read_csv('train/train6409.tsv', sep='\t', encoding='utf8')
for i in indices:
    train_labeled_df[train_labeled_df['label_id'] == i].to_csv('labels/%d.tsv' % i, sep='\t', encoding='utf8',
                                                               index=None)
train_labeled_df
# Out:
#        label_id                                               text
# 0             0  一种信号的发送方法及基站、用户设备<sep>一种信号的发送方法及基站、用户设备。在一个子帧中...
# 1             0  一种5g通讯电缆故障监控系统<sep>本发明公开了一种5g通讯电缆故障监控系统，包括信号采样...
# 2             0  一种测试方法及电子设备<sep>本发明提供了一种测试方法及电子设备，该方法包括：基于选取的测...
# 3             0  天线方位角调节装置<sep>一种天线方位角调节装置，包括对向的两个8字形支架(101)、动力...
# 4             0  光纤老化预测方法及装置<sep>本申请提供一种光纤老化预测方法及装置，所述方法包括：获取待测...
# ...         ...                                                ...
# 21925        23  由低合金碳钢制成的螺钉和制造该螺钉的方法<sep>本发明涉及一种螺钉，该螺钉具有头部、邻接的...
# 21926        13  一种铸造铝合金及其制备方法<sep>本发明提供了一种铸造铝合金及其制备方法，铸造铝合金成分包...
# 21927         9  一种显示面板及生成随机图块坐标的方法<sep>本发明提供一种显示面板，显示面板的图块具有随机...
# 21928         0  一种确定机器类通信下行控制信道重复次数的方法及基站<sep>本发明实施例涉及无线通信技术领域...
# 21929        21  一类层状钙钛矿型纳米氧化物的超级电容器电极材料<sep>本发明涉及一类层状钙钛矿型纳米氧化物...
#
# [21930 rows x 2 columns]

# %%
import numpy as np
import pandas as pd

# train_df = pd.read_csv('train_xlnet.tsv', sep='\t', encoding='utf8')
train_df = pd.read_json('train.json', encoding='utf8', lines=True)
train_labeled_df = pd.read_csv('train/train6409.tsv', sep='\t', encoding='utf8')
testA_labeled_df = pd.read_csv('test/testA_6409.tsv', sep='\t', encoding='utf8', header=0,
                               names=['label_id', 'text'])
ratios = []
for i in range(36):
    ratio = train_labeled_df[train_labeled_df['label_id'] == i].shape[0] / train_df[train_df['label_id'] == i].shape[0]
    ratios.append(ratio)
    print("%d\t%f" % (i, ratio))

np.mean(ratios)
# Out:
# 0	69.090909
# 1	37.210526
# 2	25.049180
# 3	10.242424
# 4	14.386364
# 5	32.305556
# 6	18.680851
# 7	22.770833
# 8	23.615385
# 9	15.160000
# 10	41.615385
# 11	16.222222
# 12	9.857143
# 13	32.500000
# 14	10.210526
# 15	13.727273
# 16	19.941176
# 17	18.153846
# 18	19.875000
# 19	18.076923
# 20	36.200000
# 21	37.666667
# 22	5.800000
# 23	16.272727
# 24	12.827586
# 25	12.812500
# 26	15.058824
# 27	5.545455
# 28	9.750000
# 29	11.285714
# 30	14.538462
# 31	25.500000
# 32	6.400000
# 33	17.625000
# 34	14.500000
# 35	9.333333
# 19.99466083331372

# %%
ratio = 37.0

temp_train_df = pd.DataFrame()

for i in range(36):
    # 获取当前比例
    new, origin = train_labeled_df[train_labeled_df['label_id'] == i].shape[0], train_df[train_df['label_id'] == i].shape[0]
    current_ratio = new / origin
    # 如果不够，则补充
    if current_ratio < ratio - 3.0:
        add_data = train_labeled_df[train_labeled_df['label_id'] == i]
        temp_train_df = pd.concat((temp_train_df, add_data), axis=0)
        need = origin * ratio - new

        label = train_df[train_df['label_id'] == i]
        # 如果 label 资源整体数目小于需求
        if origin < need:
            times, rest = int(need // origin), int(need % origin)
            # 添加 times 倍的全量数据
            for t in range(times):
                add_data = train_labeled_df[train_labeled_df['label_id'] == i].iloc[:origin, :]
                temp_train_df = pd.concat((temp_train_df, add_data), axis=0)
            # 添加 rest 的余量数据
            add_data = train_labeled_df[train_labeled_df['label_id'] == i].iloc[:rest, :]
            temp_train_df = pd.concat((temp_train_df, add_data), axis=0)
        # 如果满足需求，直接添加
        else:
            add_data = train_labeled_df[train_labeled_df['label_id'] == i].iloc[:need, :]
            temp_train_df = pd.concat((temp_train_df, add_data), axis=0)
    else:
        # 如果超过一定的比例，则削减
        ALLOW = 15.0
        if current_ratio - ratio > ALLOW:
            need = int(origin * (ratio + ALLOW))
            add_data = train_labeled_df[train_labeled_df['label_id'] == i].iloc[:need, :]
            temp_train_df = pd.concat((temp_train_df, add_data), axis=0)
        else:
            add_data = train_labeled_df[train_labeled_df['label_id'] == i]
            temp_train_df = pd.concat((temp_train_df, add_data), axis=0)

ratios = []
for i in range(36):
    ratio = temp_train_df[temp_train_df['label_id'] == i].shape[0] / train_df[train_df['label_id'] == i].shape[0]
    ratios.append(ratio)
    print("%d\t%f" % (i, ratio))

temp_train_df.to_csv('train/train6409oversampling_37.tsv', sep='\t', encoding='utf8', index=None)
np.mean(ratios)
# Out:
# 0	52.000000
# 1	37.210526
# 2	37.000000
# 3	37.000000
# 4	37.000000
# 5	37.000000
# 6	37.000000
# 7	37.000000
# 8	37.000000
# 9	37.000000
# 10	41.615385
# 11	37.000000
# 12	37.000000
# 13	37.000000
# 14	37.000000
# 15	37.000000
# 16	37.000000
# 17	37.000000
# 18	37.000000
# 19	37.000000
# 20	36.200000
# 21	37.666667
# 22	37.000000
# 23	37.000000
# 24	37.000000
# 25	37.000000
# 26	37.000000
# 27	37.000000
# 28	37.000000
# 29	37.000000
# 30	37.000000
# 31	37.000000
# 32	37.000000
# 33	37.000000
# 34	37.000000
# 35	37.000000
# 37.54701604438446

# %%
testA_labeled_df = pd.read_csv('train/train6337oversampling_sort.tsv', sep='\t', encoding='utf8', header=0,
                               names=['label_id', 'text'])
testA_labeled_df = testA_labeled_df.sort_values('label_id')
testA_labeled_df.to_csv('train/train6337oversampling_sort.tsv', sep='\t', encoding='utf8', index=None)
testA_labeled_df
# Out:
#        label_id                                               text
# 0             0  一种信号的发送方法及基站、用户设备<sep>一种信号的发送方法及基站、用户设备。在一个子帧中...
# 1267          0  一种哈希冲突的处理方法、装置及交换设备<sep>本发明提供了一种mac地址哈希冲突的处理方法...
# 1266          0  传输、获取上行harq反馈信息的方法及装置<sep>本公开提供一种传输、获取上行harq反馈...
# 1265          0  数据传输方法和设备<sep>本申请提供了一种数据传输方法和设备，终端设备从源接入网设备向目标...
# 1264          0  一种用于自定义高速接口与以太网交互的路由控制系统<sep>本发明公开了一种用于自定义高速接口...
# ...         ...                                                ...
# 21302        35  数值转移方法、装置、计算机设备和存储介质<sep>本申请涉及一种数值转移方法、系统、计算机设...
# 21303        35  一种基于社交关系的原生信息流代投广告实现方法及系统<sep>本发明实施例提供一种基于社交关系...
# 21304        35  一种处理网页信息的方法及装置<sep>本发明公开了一种处理网页信息的方法，包括：中间组件接收...
# 21306        35  一种信息投放方法及装置<sep>本发明公开了一种信息投放方法及装置，所述方法包括：确定目标用...
# 23111        35  一种信息投放方法及装置<sep>本发明公开了一种信息投放方法及装置，所述方法包括：确定目标用...
#
# [23112 rows x 2 columns]

# %%
test = pd.read_csv('test/testA_6337.tsv', encoding='utf8', sep='\t')
test[test['text'].str.contains('农业') & test['text'].str.contains('养殖')]
# Out:
#        label                                               text
# 6874       1  一种基于水芹种植塘的甲鱼生态共生养殖方法<sep>一种基于水芹种植塘的甲鱼生态共生养殖方法，...
# 7544       1  一种多维生态稻田的种植养殖模式<sep>本发明公开了一种多维生态稻田的种植养殖模式，包括如下...
# 9412       7  一种碳基助剂强化催化过硫酸盐的水处理方法<sep>本发明以一种水钠锰矿负载碳基材料作为催化助...
# 12370      1  一种生物垫料菌纳豆芽孢杆菌的生产工艺<sep>本发明公开了一种生物垫料菌纳豆芽孢杆菌的生产工...
